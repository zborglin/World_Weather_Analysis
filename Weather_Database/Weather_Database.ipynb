# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from scipy.stats import linregress

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a list for holding the cities.
cities = []
# Create an empty list to hold the weather data
city_data = []

# Create counters
record_count = 1
set_count = 1

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#print(coordinates)
len(coordinates)
# Out:
# 2000

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Loop through all the cities in our list

# Print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | uk
# City not found. Skipping...
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | thinadhoo
# Processing Record 5 of Set 1 | bikaner
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | strelka
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | lagoa
# Processing Record 12 of Set 1 | beringovskiy
# Processing Record 13 of Set 1 | kahului
# Processing Record 14 of Set 1 | aitape
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | leningradskiy
# Processing Record 17 of Set 1 | parangan
# Processing Record 18 of Set 1 | touros
# Processing Record 19 of Set 1 | pevek
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | feijo
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | mwene-ditu
# Processing Record 26 of Set 1 | olga
# Processing Record 27 of Set 1 | ondangwa
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | dickinson
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | esperance
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | richards bay
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | sinjai
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | anadyr
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | odweyne
# Processing Record 46 of Set 1 | megion
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | shenjiamen
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | duiwelskloof
# Processing Record 1 of Set 2 | sistranda
# Processing Record 2 of Set 2 | kathmandu
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | gushikawa
# Processing Record 7 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 2 | karpogory
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | voh
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | dauriya
# Processing Record 14 of Set 2 | maniitsoq
# Processing Record 15 of Set 2 | mirante do paranapanema
# Processing Record 16 of Set 2 | tignere
# Processing Record 17 of Set 2 | porbandar
# Processing Record 18 of Set 2 | haines junction
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | raudeberg
# Processing Record 21 of Set 2 | carutapera
# Processing Record 22 of Set 2 | mananjary
# Processing Record 23 of Set 2 | muli
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | panguna
# Processing Record 28 of Set 2 | kingston upon hull
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | algeciras
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | umm lajj
# Processing Record 33 of Set 2 | nanortalik
# Processing Record 34 of Set 2 | tawnat
# City not found. Skipping...
# Processing Record 35 of Set 2 | chaykovskaya
# Processing Record 36 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 2 | rio claro
# Processing Record 38 of Set 2 | george town
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | farafangana
# Processing Record 41 of Set 2 | kieta
# Processing Record 42 of Set 2 | san andres
# Processing Record 43 of Set 2 | narsaq
# Processing Record 44 of Set 2 | naze
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | kisangani
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | mayor pablo lagerenza
# Processing Record 50 of Set 2 | la ronge
# Processing Record 1 of Set 3 | norman wells
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | cabo san lucas
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | namibe
# Processing Record 6 of Set 3 | binga
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | kitimat
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | buraydah
# Processing Record 12 of Set 3 | townsville
# Processing Record 13 of Set 3 | sorong
# Processing Record 14 of Set 3 | west bay
# Processing Record 15 of Set 3 | kapaa
# Processing Record 16 of Set 3 | fort nelson
# Processing Record 17 of Set 3 | valparaiso
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | port hedland
# Processing Record 22 of Set 3 | galesong
# Processing Record 23 of Set 3 | yuli
# Processing Record 24 of Set 3 | davila
# Processing Record 25 of Set 3 | araruama
# Processing Record 26 of Set 3 | saquena
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | vila franca do campo
# Processing Record 29 of Set 3 | mahasamund
# Processing Record 30 of Set 3 | ayagoz
# Processing Record 31 of Set 3 | bergen
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | kalundborg
# Processing Record 34 of Set 3 | padang
# Processing Record 35 of Set 3 | portland
# Processing Record 36 of Set 3 | rio gallegos
# Processing Record 37 of Set 3 | margate
# Processing Record 38 of Set 3 | hargeysa
# Processing Record 39 of Set 3 | basar
# Processing Record 40 of Set 3 | moranbah
# Processing Record 41 of Set 3 | bongandanga
# Processing Record 42 of Set 3 | namatanai
# Processing Record 43 of Set 3 | koscian
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 3 | coahuayana
# Processing Record 47 of Set 3 | moron
# Processing Record 48 of Set 3 | port macquarie
# Processing Record 49 of Set 3 | bonfim
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | chernyshevskiy
# Processing Record 2 of Set 4 | rocha
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | sola
# Processing Record 6 of Set 4 | guerrero negro
# Processing Record 7 of Set 4 | madang
# Processing Record 8 of Set 4 | krasnoturansk
# Processing Record 9 of Set 4 | iquique
# Processing Record 10 of Set 4 | yatou
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | atikokan
# Processing Record 13 of Set 4 | angoche
# Processing Record 14 of Set 4 | arman
# Processing Record 15 of Set 4 | iguape
# Processing Record 16 of Set 4 | dikson
# Processing Record 17 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 4 | batagay
# Processing Record 19 of Set 4 | grand-lahou
# Processing Record 20 of Set 4 | cockburn town
# Processing Record 21 of Set 4 | killybegs
# Processing Record 22 of Set 4 | honningsvag
# Processing Record 23 of Set 4 | innisfail
# Processing Record 24 of Set 4 | zheleznodorozhnyy
# Processing Record 25 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 4 | taoudenni
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | sao luiz gonzaga
# Processing Record 29 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 4 | airai
# Processing Record 31 of Set 4 | sofiysk
# City not found. Skipping...
# Processing Record 32 of Set 4 | bamiantong
# Processing Record 33 of Set 4 | judaberg
# Processing Record 34 of Set 4 | kumluca
# Processing Record 35 of Set 4 | havre-saint-pierre
# Processing Record 36 of Set 4 | salalah
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | saint george
# Processing Record 39 of Set 4 | yellowknife
# Processing Record 40 of Set 4 | teguise
# Processing Record 41 of Set 4 | dom pedro
# Processing Record 42 of Set 4 | fatick
# Processing Record 43 of Set 4 | tual
# Processing Record 44 of Set 4 | kaitangata
# Processing Record 45 of Set 4 | lyngseidet
# Processing Record 46 of Set 4 | magistralnyy
# Processing Record 47 of Set 4 | lavrentiya
# Processing Record 48 of Set 4 | bredasdorp
# Processing Record 49 of Set 4 | xining
# Processing Record 50 of Set 4 | san quintin
# Processing Record 1 of Set 5 | vaitape
# Processing Record 2 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 5 | mbandaka
# Processing Record 4 of Set 5 | butaritari
# Processing Record 5 of Set 5 | westport
# Processing Record 6 of Set 5 | bengkulu
# Processing Record 7 of Set 5 | khowst
# Processing Record 8 of Set 5 | venezuela
# Processing Record 9 of Set 5 | port lincoln
# Processing Record 10 of Set 5 | christiana
# Processing Record 11 of Set 5 | nioro
# Processing Record 12 of Set 5 | semnan
# Processing Record 13 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 5 | port hardy
# Processing Record 15 of Set 5 | kirakira
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | pravda
# Processing Record 18 of Set 5 | russkaya polyana
# Processing Record 19 of Set 5 | fonte boa
# Processing Record 20 of Set 5 | kerema
# Processing Record 21 of Set 5 | havelock
# Processing Record 22 of Set 5 | faanui
# Processing Record 23 of Set 5 | ballstad
# City not found. Skipping...
# Processing Record 24 of Set 5 | boyolangu
# Processing Record 25 of Set 5 | urumqi
# Processing Record 26 of Set 5 | wasilla
# Processing Record 27 of Set 5 | handan
# Processing Record 28 of Set 5 | hirara
# Processing Record 29 of Set 5 | havoysund
# Processing Record 30 of Set 5 | jos
# Processing Record 31 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 5 | severo-kurilsk
# Processing Record 33 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | lander
# Processing Record 36 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 5 | port keats
# Processing Record 38 of Set 5 | dzilam gonzalez
# Processing Record 39 of Set 5 | kavaratti
# Processing Record 40 of Set 5 | baijiantan
# Processing Record 41 of Set 5 | goksun
# Processing Record 42 of Set 5 | paamiut
# Processing Record 43 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 5 | el colomo
# Processing Record 45 of Set 5 | mariestad
# Processing Record 46 of Set 5 | banda aceh
# Processing Record 47 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 5 | lewiston
# Processing Record 49 of Set 5 | montemor-o-novo
# Processing Record 50 of Set 5 | lubao
# Processing Record 1 of Set 6 | fortuna
# Processing Record 2 of Set 6 | batticaloa
# Processing Record 3 of Set 6 | siguiri
# Processing Record 4 of Set 6 | coquimbo
# Processing Record 5 of Set 6 | gamba
# Processing Record 6 of Set 6 | kihei
# Processing Record 7 of Set 6 | bereda
# Processing Record 8 of Set 6 | witrivier
# City not found. Skipping...
# Processing Record 9 of Set 6 | akureyri
# Processing Record 10 of Set 6 | san rafael
# Processing Record 11 of Set 6 | capelinha
# Processing Record 12 of Set 6 | cherskiy
# Processing Record 13 of Set 6 | phalombe
# Processing Record 14 of Set 6 | buluang
# Processing Record 15 of Set 6 | staraya mayna
# Processing Record 16 of Set 6 | play cu
# City not found. Skipping...
# Processing Record 17 of Set 6 | saint-philippe
# Processing Record 18 of Set 6 | ixtapa
# Processing Record 19 of Set 6 | imamoglu
# Processing Record 20 of Set 6 | askino
# Processing Record 21 of Set 6 | bubaque
# Processing Record 22 of Set 6 | abu dhabi
# Processing Record 23 of Set 6 | casper
# Processing Record 24 of Set 6 | jumla
# Processing Record 25 of Set 6 | khorixas
# Processing Record 26 of Set 6 | half moon bay
# Processing Record 27 of Set 6 | chokurdakh
# Processing Record 28 of Set 6 | hamilton
# Processing Record 29 of Set 6 | bayir
# Processing Record 30 of Set 6 | yeppoon
# Processing Record 31 of Set 6 | sao filipe
# Processing Record 32 of Set 6 | puerto escondido
# Processing Record 33 of Set 6 | shimoda
# Processing Record 34 of Set 6 | san patricio
# Processing Record 35 of Set 6 | kurya
# Processing Record 36 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 37 of Set 6 | carrigaline
# Processing Record 38 of Set 6 | hoa binh
# Processing Record 39 of Set 6 | eyl
# Processing Record 40 of Set 6 | puqi
# Processing Record 41 of Set 6 | nizhniy kuranakh
# Processing Record 42 of Set 6 | bluff
# Processing Record 43 of Set 6 | clyde river
# Processing Record 44 of Set 6 | svetlyy
# Processing Record 45 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 6 | ucluelet
# Processing Record 47 of Set 6 | wajid
# Processing Record 48 of Set 6 | ikwiriri
# Processing Record 49 of Set 6 | tuatapere
# Processing Record 50 of Set 6 | ancud
# Processing Record 1 of Set 7 | uribia
# Processing Record 2 of Set 7 | hasaki
# Processing Record 3 of Set 7 | pitkyaranta
# Processing Record 4 of Set 7 | promyshlennaya
# Processing Record 5 of Set 7 | cardenas
# Processing Record 6 of Set 7 | umea
# Processing Record 7 of Set 7 | alta floresta
# Processing Record 8 of Set 7 | bathsheba
# Processing Record 9 of Set 7 | kongoussi
# Processing Record 10 of Set 7 | barguzin
# Processing Record 11 of Set 7 | katherine
# Processing Record 12 of Set 7 | vershino-shakhtaminskiy
# Processing Record 13 of Set 7 | rupert
# Processing Record 14 of Set 7 | scarborough
# Processing Record 15 of Set 7 | liverpool
# Processing Record 16 of Set 7 | sorland
# Processing Record 17 of Set 7 | la rioja
# Processing Record 18 of Set 7 | vanderhoof
# Processing Record 19 of Set 7 | asamankese
# Processing Record 20 of Set 7 | kaura namoda
# Processing Record 21 of Set 7 | cachoeiro de itapemirim
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | iqaluit
# Processing Record 24 of Set 7 | cidreira
# Processing Record 25 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 26 of Set 7 | phangnga
# Processing Record 27 of Set 7 | mount gambier
# Processing Record 28 of Set 7 | umm bab
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | katobu
# Processing Record 31 of Set 7 | teknaf
# Processing Record 32 of Set 7 | saravan
# Processing Record 33 of Set 7 | salinas
# Processing Record 34 of Set 7 | sainte-thecle
# Processing Record 35 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 36 of Set 7 | talnakh
# Processing Record 37 of Set 7 | ahipara
# Processing Record 38 of Set 7 | tiksi
# Processing Record 39 of Set 7 | elizabeth city
# Processing Record 40 of Set 7 | hanchuan
# Processing Record 41 of Set 7 | zhezkazgan
# Processing Record 42 of Set 7 | sitka
# Processing Record 43 of Set 7 | khani
# Processing Record 44 of Set 7 | ambilobe
# Processing Record 45 of Set 7 | kulhudhuffushi
# Processing Record 46 of Set 7 | sao joao da barra
# Processing Record 47 of Set 7 | taltal
# Processing Record 48 of Set 7 | sinnamary
# Processing Record 49 of Set 7 | sawakin
# Processing Record 50 of Set 7 | changqing
# Processing Record 1 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | vanimo
# Processing Record 4 of Set 8 | mamallapuram
# Processing Record 5 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 8 | amga
# Processing Record 7 of Set 8 | oskaloosa
# Processing Record 8 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 8 | french harbor
# Processing Record 10 of Set 8 | chaiyaphum
# Processing Record 11 of Set 8 | tianpeng
# Processing Record 12 of Set 8 | nouadhibou
# Processing Record 13 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 8 | los llanos de aridane
# Processing Record 15 of Set 8 | beisfjord
# Processing Record 16 of Set 8 | colares
# Processing Record 17 of Set 8 | gomel
# Processing Record 18 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 8 | cururupu
# Processing Record 20 of Set 8 | remedios
# Processing Record 21 of Set 8 | boguchany
# Processing Record 22 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 24 of Set 8 | cleethorpes
# Processing Record 25 of Set 8 | auki
# Processing Record 26 of Set 8 | koslan
# Processing Record 27 of Set 8 | lompoc
# Processing Record 28 of Set 8 | manzhouli
# Processing Record 29 of Set 8 | san jose
# Processing Record 30 of Set 8 | vestmannaeyjar
# Processing Record 31 of Set 8 | tiznit
# Processing Record 32 of Set 8 | azambuja
# Processing Record 33 of Set 8 | gat
# Processing Record 34 of Set 8 | anchorage
# Processing Record 35 of Set 8 | huangnihe
# Processing Record 36 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 8 | faya
# Processing Record 38 of Set 8 | solton
# Processing Record 39 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 40 of Set 8 | cubuk
# Processing Record 41 of Set 8 | alofi
# Processing Record 42 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 8 | ranong
# Processing Record 44 of Set 8 | bonthe
# Processing Record 45 of Set 8 | abu kamal
# Processing Record 46 of Set 8 | mananara
# Processing Record 47 of Set 8 | elbistan
# Processing Record 48 of Set 8 | bilibino
# Processing Record 49 of Set 8 | kruisfontein
# Processing Record 50 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 1 of Set 9 | asahikawa
# Processing Record 2 of Set 9 | celestun
# Processing Record 3 of Set 9 | srandakan
# Processing Record 4 of Set 9 | xingyi
# Processing Record 5 of Set 9 | kifri
# Processing Record 6 of Set 9 | robertson
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 9 | presidencia roque saenz pena
# Processing Record 10 of Set 9 | berlevag
# Processing Record 11 of Set 9 | srivardhan
# Processing Record 12 of Set 9 | comodoro rivadavia
# Processing Record 13 of Set 9 | saint-pierre
# Processing Record 14 of Set 9 | hengshui
# Processing Record 15 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 9 | sehore
# Processing Record 17 of Set 9 | russell
# Processing Record 18 of Set 9 | otane
# Processing Record 19 of Set 9 | pemba
# Processing Record 20 of Set 9 | leh
# Processing Record 21 of Set 9 | emerald
# Processing Record 22 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 9 | tabas
# Processing Record 24 of Set 9 | tukrah
# Processing Record 25 of Set 9 | dunedin
# Processing Record 26 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 9 | uige
# Processing Record 28 of Set 9 | grand gaube
# Processing Record 29 of Set 9 | imbituba
# Processing Record 30 of Set 9 | hovd
# Processing Record 31 of Set 9 | akyab
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | husavik
# Processing Record 34 of Set 9 | marrakesh
# Processing Record 35 of Set 9 | surt
# Processing Record 36 of Set 9 | manaus
# Processing Record 37 of Set 9 | shaowu
# Processing Record 38 of Set 9 | talalayivka
# Processing Record 39 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 9 | poum
# Processing Record 41 of Set 9 | alekseyevka
# Processing Record 42 of Set 9 | camapua
# Processing Record 43 of Set 9 | solenzo
# Processing Record 44 of Set 9 | vila velha
# Processing Record 45 of Set 9 | nicoya
# Processing Record 46 of Set 9 | podlesnyy
# Processing Record 47 of Set 9 | erdaojiang
# Processing Record 48 of Set 9 | ippy
# Processing Record 49 of Set 9 | eureka
# Processing Record 50 of Set 9 | fairbanks
# Processing Record 1 of Set 10 | yilan
# Processing Record 2 of Set 10 | zlatarica
# City not found. Skipping...
# Processing Record 3 of Set 10 | dingle
# Processing Record 4 of Set 10 | abaza
# Processing Record 5 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 10 | santa rosalia
# Processing Record 7 of Set 10 | lata
# Processing Record 8 of Set 10 | mahebourg
# Processing Record 9 of Set 10 | dogondoutchi
# Processing Record 10 of Set 10 | bokovskaya
# Processing Record 11 of Set 10 | kharp
# Processing Record 12 of Set 10 | moree
# Processing Record 13 of Set 10 | puerto concordia
# Processing Record 14 of Set 10 | tambopata
# Processing Record 15 of Set 10 | sisimiut
# Processing Record 16 of Set 10 | mazsalaca
# Processing Record 17 of Set 10 | upata
# Processing Record 18 of Set 10 | katima mulilo
# Processing Record 19 of Set 10 | takoradi
# Processing Record 20 of Set 10 | sao gabriel da cachoeira
# Processing Record 21 of Set 10 | shar
# Processing Record 22 of Set 10 | khalkhal
# Processing Record 23 of Set 10 | santa cruz
# Processing Record 24 of Set 10 | awjilah
# Processing Record 25 of Set 10 | prince rupert
# Processing Record 26 of Set 10 | trairi
# Processing Record 27 of Set 10 | dolores hidalgo
# Processing Record 28 of Set 10 | mahibadhoo
# Processing Record 29 of Set 10 | asau
# Processing Record 30 of Set 10 | biak
# Processing Record 31 of Set 10 | kushmurun
# Processing Record 32 of Set 10 | port blair
# Processing Record 33 of Set 10 | izhma
# Processing Record 34 of Set 10 | hay river
# Processing Record 35 of Set 10 | ibra
# Processing Record 36 of Set 10 | burns lake
# Processing Record 37 of Set 10 | yulara
# Processing Record 38 of Set 10 | cukai
# Processing Record 39 of Set 10 | bac lieu
# Processing Record 40 of Set 10 | port augusta
# Processing Record 41 of Set 10 | santiago del estero
# Processing Record 42 of Set 10 | pombas
# Processing Record 43 of Set 10 | ust-kuyga
# Processing Record 44 of Set 10 | prainha
# Processing Record 45 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 10 | ketchikan
# Processing Record 47 of Set 10 | val-david
# Processing Record 48 of Set 10 | sao miguel do araguaia
# Processing Record 49 of Set 10 | the valley
# Processing Record 50 of Set 10 | seoul
# Processing Record 1 of Set 11 | austin
# Processing Record 2 of Set 11 | grindavik
# Processing Record 3 of Set 11 | strezhevoy
# Processing Record 4 of Set 11 | isla vista
# Processing Record 5 of Set 11 | gbarnga
# Processing Record 6 of Set 11 | neiafu
# Processing Record 7 of Set 11 | vila praia de ancora
# Processing Record 8 of Set 11 | tigil
# Processing Record 9 of Set 11 | puerto leguizamo
# Processing Record 10 of Set 11 | dravograd
# Processing Record 11 of Set 11 | lumphat
# Processing Record 12 of Set 11 | vostok
# Processing Record 13 of Set 11 | raga
# Processing Record 14 of Set 11 | mwinilunga
# Processing Record 15 of Set 11 | manggar
# Processing Record 16 of Set 11 | saint-augustin
# Processing Record 17 of Set 11 | la sarre
# Processing Record 18 of Set 11 | mitu
# Processing Record 19 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 11 | samarai
# Processing Record 21 of Set 11 | laguna
# Processing Record 22 of Set 11 | matara
# Processing Record 23 of Set 11 | hambantota
# Processing Record 24 of Set 11 | yamada
# Processing Record 25 of Set 11 | olafsvik
# Processing Record 26 of Set 11 | te anau
# Processing Record 27 of Set 11 | luanda
# Processing Record 28 of Set 11 | natal
# Processing Record 29 of Set 11 | verkhoyansk
# Processing Record 30 of Set 11 | lleida
# Processing Record 31 of Set 11 | qaqortoq
# Processing Record 32 of Set 11 | rasshevatskaya
# Processing Record 33 of Set 11 | morehead
# Processing Record 34 of Set 11 | barquisimeto
# Processing Record 35 of Set 11 | atherton
# Processing Record 36 of Set 11 | miramar
# Processing Record 37 of Set 11 | odesskoye
# Processing Record 38 of Set 11 | borovoy
# Processing Record 39 of Set 11 | manassas park
# Processing Record 40 of Set 11 | martapura
# Processing Record 41 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 42 of Set 11 | veraval
# Processing Record 43 of Set 11 | demirci
# Processing Record 44 of Set 11 | san fernando
# Processing Record 45 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 46 of Set 11 | rustenburg
# Processing Record 47 of Set 11 | corrales
# Processing Record 48 of Set 11 | nemuro
# Processing Record 49 of Set 11 | pangnirtung
# Processing Record 50 of Set 11 | hualmay
# Processing Record 1 of Set 12 | porto murtinho
# Processing Record 2 of Set 12 | qarqin
# Processing Record 3 of Set 12 | praia
# Processing Record 4 of Set 12 | alugan
# Processing Record 5 of Set 12 | kristiinankaupunki
# Processing Record 6 of Set 12 | tirur
# Processing Record 7 of Set 12 | wilmington
# Processing Record 8 of Set 12 | ugoofaaru
# Processing Record 9 of Set 12 | maragogi
# Processing Record 10 of Set 12 | serebryansk
# Processing Record 11 of Set 12 | ratnagiri
# Processing Record 12 of Set 12 | dalby
# Processing Record 13 of Set 12 | carauari
# Processing Record 14 of Set 12 | paraiso
# Processing Record 15 of Set 12 | saint anthony
# Processing Record 16 of Set 12 | saldanha
# Processing Record 17 of Set 12 | normal
# Processing Record 18 of Set 12 | pont-saint-esprit
# Processing Record 19 of Set 12 | songjianghe
# Processing Record 20 of Set 12 | komsomolskiy
# Processing Record 21 of Set 12 | shuangyang
# Processing Record 22 of Set 12 | paciran
# Processing Record 23 of Set 12 | kedougou
# Processing Record 24 of Set 12 | muisne
# Processing Record 25 of Set 12 | roma
# Processing Record 26 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 27 of Set 12 | kavieng
# Processing Record 28 of Set 12 | atyrau
# Processing Record 29 of Set 12 | cervo
# Processing Record 30 of Set 12 | beloha
# Processing Record 31 of Set 12 | puerto baquerizo moreno
# Processing Record 32 of Set 12 | gizo
# Processing Record 33 of Set 12 | san angelo
# Processing Record 34 of Set 12 | luderitz
# Processing Record 35 of Set 12 | itarema
# Processing Record 36 of Set 12 | borsbeek
# Processing Record 37 of Set 12 | winnemucca
# Processing Record 38 of Set 12 | atar
# Processing Record 39 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 40 of Set 12 | moerai
# Processing Record 41 of Set 12 | mbanza-ngungu
# Processing Record 42 of Set 12 | matagami
# Processing Record 43 of Set 12 | tecoanapa
# Processing Record 44 of Set 12 | tahoua
# Processing Record 45 of Set 12 | bowen
# Processing Record 46 of Set 12 | sabha
# Processing Record 47 of Set 12 | kribi
# Processing Record 48 of Set 12 | quatre cocos
# Processing Record 49 of Set 12 | shelburne
# Processing Record 50 of Set 12 | talara
# Processing Record 1 of Set 13 | labuhan
# Processing Record 2 of Set 13 | sheregesh
# Processing Record 3 of Set 13 | port-gentil
# Processing Record 4 of Set 13 | exeter
# Processing Record 5 of Set 13 | ternate
# Processing Record 6 of Set 13 | pyatovskiy
# Processing Record 7 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 13 | touba
# Processing Record 9 of Set 13 | plettenberg bay
# Processing Record 10 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 13 | sinegorskiy
# Processing Record 12 of Set 13 | oksfjord
# Processing Record 13 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 14 of Set 13 | honiara
# Processing Record 15 of Set 13 | isangel
# Processing Record 16 of Set 13 | korla
# Processing Record 17 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 13 | diffa
# Processing Record 19 of Set 13 | zyryanka
# Processing Record 20 of Set 13 | koutsouras
# Processing Record 21 of Set 13 | terrace
# Processing Record 22 of Set 13 | mancio lima
# Processing Record 23 of Set 13 | chumikan
# Processing Record 24 of Set 13 | romny
# Processing Record 25 of Set 13 | mongomo
# Processing Record 26 of Set 13 | aswan
# Processing Record 27 of Set 13 | port moresby
# Processing Record 28 of Set 13 | rawson
# Processing Record 29 of Set 13 | ust-kulom
# Processing Record 30 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 13 | marsa matruh
# Processing Record 32 of Set 13 | winston-salem
# Processing Record 33 of Set 13 | pascagoula
# Processing Record 34 of Set 13 | tarija
# Processing Record 35 of Set 13 | smoky lake
# Processing Record 36 of Set 13 | asfi
# Processing Record 37 of Set 13 | ledec
# Processing Record 38 of Set 13 | jiujiang
# Processing Record 39 of Set 13 | aleksandrov gay
# Processing Record 40 of Set 13 | yerbogachen
# Processing Record 41 of Set 13 | morondava
# Processing Record 42 of Set 13 | bijar
# Processing Record 43 of Set 13 | kichera
# Processing Record 44 of Set 13 | kachug
# Processing Record 45 of Set 13 | jaisalmer
# Processing Record 46 of Set 13 | burnie
# Processing Record 47 of Set 13 | boke
# Processing Record 48 of Set 13 | batsfjord
# Processing Record 49 of Set 13 | almaznyy
# Processing Record 50 of Set 13 | russkiy aktash
# Processing Record 1 of Set 14 | gualaquiza
# Processing Record 2 of Set 14 | adet
# Processing Record 3 of Set 14 | palauig
# Processing Record 4 of Set 14 | ojinaga
# Processing Record 5 of Set 14 | krnov
# Processing Record 6 of Set 14 | khasan
# Processing Record 7 of Set 14 | coaldale
# Processing Record 8 of Set 14 | sovetskaya gavan
# Processing Record 9 of Set 14 | flin flon
# Processing Record 10 of Set 14 | takaka
# Processing Record 11 of Set 14 | urengoy
# Processing Record 12 of Set 14 | jizan
# Processing Record 13 of Set 14 | great bend
# Processing Record 14 of Set 14 | guarapari
# Processing Record 15 of Set 14 | borba
# Processing Record 16 of Set 14 | mehamn
# Processing Record 17 of Set 14 | woodward
# Processing Record 18 of Set 14 | el alto
# Processing Record 19 of Set 14 | kajaani
# Processing Record 20 of Set 14 | coihaique
# Processing Record 21 of Set 14 | ostrovnoy
# Processing Record 22 of Set 14 | aden
# Processing Record 23 of Set 14 | miyako
# Processing Record 24 of Set 14 | livny
# Processing Record 25 of Set 14 | shakawe
# Processing Record 26 of Set 14 | pakokku
# Processing Record 27 of Set 14 | nogliki
# Processing Record 28 of Set 14 | mereni
# Processing Record 29 of Set 14 | miyoshi
# Processing Record 30 of Set 14 | amapa
# Processing Record 31 of Set 14 | karratha
# Processing Record 32 of Set 14 | cobija
# Processing Record 33 of Set 14 | brae
# Processing Record 34 of Set 14 | prieska
# Processing Record 35 of Set 14 | maldonado
# Processing Record 36 of Set 14 | the pas
# Processing Record 37 of Set 14 | at-bashi
# Processing Record 38 of Set 14 | estevan
# Processing Record 39 of Set 14 | lasa
# Processing Record 40 of Set 14 | abu samrah
# Processing Record 41 of Set 14 | sabang
# Processing Record 42 of Set 14 | baikunthpur
# Processing Record 43 of Set 14 | bilma
# Processing Record 44 of Set 14 | kuytun
# Processing Record 45 of Set 14 | andros town
# Processing Record 46 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 47 of Set 14 | iaciara
# Processing Record 48 of Set 14 | bolkhov
# Processing Record 49 of Set 14 | hangu
# Processing Record 50 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 15 | otradnoye
# Processing Record 2 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 15 | kayunga
# Processing Record 4 of Set 15 | sao felix do xingu
# Processing Record 5 of Set 15 | haimen
# Processing Record 6 of Set 15 | ercis
# Processing Record 7 of Set 15 | lazaro cardenas
# Processing Record 8 of Set 15 | oussouye
# Processing Record 9 of Set 15 | waipawa
# Processing Record 10 of Set 15 | arrecife
# Processing Record 11 of Set 15 | novikovo
# Processing Record 12 of Set 15 | satara
# Processing Record 13 of Set 15 | ipora
# Processing Record 14 of Set 15 | cape coast
# Processing Record 15 of Set 15 | san-pedro
# Processing Record 16 of Set 15 | souflion
# City not found. Skipping...
# Processing Record 17 of Set 15 | sembakung
# Processing Record 18 of Set 15 | biedenkopf
# Processing Record 19 of Set 15 | maine-soroa
# Processing Record 20 of Set 15 | cayenne
# Processing Record 21 of Set 15 | haines city
# Processing Record 22 of Set 15 | dekernes
# Processing Record 23 of Set 15 | berezovka
# Processing Record 24 of Set 15 | washougal
# Processing Record 25 of Set 15 | caravelas
# Processing Record 26 of Set 15 | kenai
# Processing Record 27 of Set 15 | torrington
# Processing Record 28 of Set 15 | patu
# Processing Record 29 of Set 15 | poronaysk
# Processing Record 30 of Set 15 | gaomi
# Processing Record 31 of Set 15 | tchollire
# Processing Record 32 of Set 15 | shancheng
# Processing Record 33 of Set 15 | ajtos
# Processing Record 34 of Set 15 | jining
# Processing Record 35 of Set 15 | palmas bellas
# Processing Record 36 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 15 | sumbe
# Processing Record 38 of Set 15 | huarmey
# Processing Record 39 of Set 15 | tarabuco
# Processing Record 40 of Set 15 | krasnoselkup
# Processing Record 41 of Set 15 | sovetskiy
# Processing Record 42 of Set 15 | kandara
# Processing Record 43 of Set 15 | jalu
# Processing Record 44 of Set 15 | marsh harbour
# Processing Record 45 of Set 15 | qasigiannguit
# Processing Record 46 of Set 15 | santo tomas
# Processing Record 47 of Set 15 | bay city
# Processing Record 48 of Set 15 | tsabong
# Processing Record 49 of Set 15 | indramayu
# Processing Record 50 of Set 15 | itaituba
# Processing Record 1 of Set 16 | inhambane
# Processing Record 2 of Set 16 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 3 of Set 16 | bagdarin
# Processing Record 4 of Set 16 | kozhva
# Processing Record 5 of Set 16 | sterling
# Processing Record 6 of Set 16 | muros
# Processing Record 7 of Set 16 | adrar
# Processing Record 8 of Set 16 | bloomfield
# Processing Record 9 of Set 16 | ferme-neuve
# Processing Record 10 of Set 16 | puerto narino
# Processing Record 11 of Set 16 | mosetse
# Processing Record 12 of Set 16 | moose factory
# Processing Record 13 of Set 16 | tikrit
# Processing Record 14 of Set 16 | weligama
# Processing Record 15 of Set 16 | kaifeng
# Processing Record 16 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 16 | stokmarknes
# Processing Record 18 of Set 16 | sioux lookout
# Processing Record 19 of Set 16 | santiago
# Processing Record 20 of Set 16 | harper
# Processing Record 21 of Set 16 | toktogul
# Processing Record 22 of Set 16 | kamina
# Processing Record 23 of Set 16 | durban
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 709

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.80  -68.30     42.08        76          36        6.62
# 1  New Norfolk -42.78  147.06     60.01        65           7        1.01
# 2    Thinadhoo   0.53   72.93     83.03        74          83       11.43
# 3      Bikaner  28.02   73.30     72.41        20           0        8.81
# 4     Hermanus -34.42   19.23     63.00        66          81        4.00
#
#   Weather Description
# 0          light rain
# 1           clear sky
# 2       broken clouds
# 3           clear sky
# 4       broken clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
