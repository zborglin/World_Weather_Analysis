# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from scipy.stats import linregress

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a list for holding the cities.
cities = []
# Create an empty list to hold the weather data
city_data = []

# Create counters
record_count = 1
set_count = 1

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#print(coordinates)
len(coordinates)
# Out:
# 2000

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Loop through all the cities in our list

# Print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 2 of Set 1 | rongcheng
# Processing Record 3 of Set 1 | kisesa
# Processing Record 4 of Set 1 | halifax
# Processing Record 5 of Set 1 | santa cruz
# Processing Record 6 of Set 1 | emba
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | college
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | fort nelson
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | bousse
# Processing Record 16 of Set 1 | filadelfia
# Processing Record 17 of Set 1 | kirakira
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | palu
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | mareeba
# Processing Record 22 of Set 1 | candawaga
# City not found. Skipping...
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | baruun-urt
# Processing Record 25 of Set 1 | ostrovnoy
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | katsuura
# Processing Record 32 of Set 1 | coahuayana
# Processing Record 33 of Set 1 | deputatskiy
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | havelock
# Processing Record 36 of Set 1 | kearney
# Processing Record 37 of Set 1 | vila franca do campo
# Processing Record 38 of Set 1 | alofi
# Processing Record 39 of Set 1 | constitucion
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | churapcha
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | ferme-neuve
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | namatanai
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | sumbe
# Processing Record 2 of Set 2 | saint anthony
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | hambantota
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | olivenza
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | honiara
# Processing Record 11 of Set 2 | tomar
# Processing Record 12 of Set 2 | nicoya
# Processing Record 13 of Set 2 | toktogul
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | narsaq
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | tura
# Processing Record 20 of Set 2 | nuuk
# Processing Record 21 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | lata
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | berlevag
# Processing Record 27 of Set 2 | alice springs
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | shimoda
# Processing Record 30 of Set 2 | fairbanks
# Processing Record 31 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | biak
# Processing Record 34 of Set 2 | kruisfontein
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | westport
# Processing Record 37 of Set 2 | indian head
# Processing Record 38 of Set 2 | makakilo city
# Processing Record 39 of Set 2 | ryotsu
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | itoman
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | muzhi
# Processing Record 45 of Set 2 | sao joao da barra
# Processing Record 46 of Set 2 | saldanha
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | sebastian
# Processing Record 49 of Set 2 | the valley
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | nelson bay
# Processing Record 4 of Set 3 | jamai
# Processing Record 5 of Set 3 | ola
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | hualmay
# Processing Record 8 of Set 3 | del rio
# Processing Record 9 of Set 3 | ahipara
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | phangnga
# Processing Record 13 of Set 3 | dakar
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | clearwater
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | pevek
# Processing Record 18 of Set 3 | sedalia
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | meulaboh
# Processing Record 21 of Set 3 | bonavista
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | nouadhibou
# Processing Record 24 of Set 3 | najran
# Processing Record 25 of Set 3 | kitale
# Processing Record 26 of Set 3 | tallahassee
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | sydney
# Processing Record 29 of Set 3 | adrar
# Processing Record 30 of Set 3 | beira
# Processing Record 31 of Set 3 | dauphin
# Processing Record 32 of Set 3 | cherskiy
# Processing Record 33 of Set 3 | graaff-reinet
# Processing Record 34 of Set 3 | bombay
# Processing Record 35 of Set 3 | beaumont
# Processing Record 36 of Set 3 | cabedelo
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | north myrtle beach
# Processing Record 39 of Set 3 | turukhansk
# Processing Record 40 of Set 3 | shingu
# Processing Record 41 of Set 3 | bulaevo
# Processing Record 42 of Set 3 | moroni
# Processing Record 43 of Set 3 | caluquembe
# Processing Record 44 of Set 3 | capoterra
# Processing Record 45 of Set 3 | vila
# Processing Record 46 of Set 3 | nabire
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | takhtamygda
# Processing Record 49 of Set 3 | vostok
# Processing Record 50 of Set 3 | vedaranniyam
# City not found. Skipping...
# Processing Record 1 of Set 4 | broome
# Processing Record 2 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | qaanaaq
# Processing Record 6 of Set 4 | nikolskoye
# Processing Record 7 of Set 4 | hereford
# Processing Record 8 of Set 4 | mbamba
# Processing Record 9 of Set 4 | raga
# Processing Record 10 of Set 4 | higuey
# City not found. Skipping...
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | pampas
# Processing Record 14 of Set 4 | hokitika
# Processing Record 15 of Set 4 | kendari
# Processing Record 16 of Set 4 | mar del plata
# Processing Record 17 of Set 4 | berea
# Processing Record 18 of Set 4 | salina
# Processing Record 19 of Set 4 | luderitz
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | denpasar
# Processing Record 22 of Set 4 | catalina
# Processing Record 23 of Set 4 | camacha
# Processing Record 24 of Set 4 | hazorasp
# Processing Record 25 of Set 4 | georgetown
# Processing Record 26 of Set 4 | banda aceh
# Processing Record 27 of Set 4 | lorengau
# Processing Record 28 of Set 4 | marzuq
# Processing Record 29 of Set 4 | axim
# Processing Record 30 of Set 4 | padang
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | saskylakh
# Processing Record 33 of Set 4 | monteagudo
# Processing Record 34 of Set 4 | porto santo
# Processing Record 35 of Set 4 | lompoc
# Processing Record 36 of Set 4 | east london
# Processing Record 37 of Set 4 | kupang
# Processing Record 38 of Set 4 | butaritari
# Processing Record 39 of Set 4 | valleyview
# Processing Record 40 of Set 4 | malyye derbety
# Processing Record 41 of Set 4 | monte alegre
# Processing Record 42 of Set 4 | port-gentil
# Processing Record 43 of Set 4 | beihai
# Processing Record 44 of Set 4 | sorland
# Processing Record 45 of Set 4 | nowogard
# Processing Record 46 of Set 4 | pacific grove
# Processing Record 47 of Set 4 | faanui
# Processing Record 48 of Set 4 | kaihua
# Processing Record 49 of Set 4 | kholm
# Processing Record 50 of Set 4 | mount isa
# Processing Record 1 of Set 5 | tautira
# Processing Record 2 of Set 5 | lesnyye polyany
# Processing Record 3 of Set 5 | leh
# Processing Record 4 of Set 5 | comodoro rivadavia
# Processing Record 5 of Set 5 | kasongo-lunda
# Processing Record 6 of Set 5 | graham
# Processing Record 7 of Set 5 | huarmey
# Processing Record 8 of Set 5 | ajdabiya
# Processing Record 9 of Set 5 | quatre cocos
# Processing Record 10 of Set 5 | brawley
# Processing Record 11 of Set 5 | cockburn town
# Processing Record 12 of Set 5 | sheridan
# Processing Record 13 of Set 5 | port hedland
# Processing Record 14 of Set 5 | dezhou
# Processing Record 15 of Set 5 | belaya gora
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | lagoa
# Processing Record 18 of Set 5 | tiznit
# Processing Record 19 of Set 5 | sovetskiy
# Processing Record 20 of Set 5 | barkhera
# Processing Record 21 of Set 5 | andrushivka
# Processing Record 22 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 5 | maldonado
# Processing Record 24 of Set 5 | bethel
# Processing Record 25 of Set 5 | awjilah
# Processing Record 26 of Set 5 | rovaniemi
# Processing Record 27 of Set 5 | hue
# Processing Record 28 of Set 5 | vilhena
# Processing Record 29 of Set 5 | chiredzi
# Processing Record 30 of Set 5 | assiniboia
# Processing Record 31 of Set 5 | shirokiy
# Processing Record 32 of Set 5 | archidona
# Processing Record 33 of Set 5 | mehamn
# Processing Record 34 of Set 5 | vao
# Processing Record 35 of Set 5 | mindelo
# Processing Record 36 of Set 5 | watsa
# Processing Record 37 of Set 5 | barcelona
# Processing Record 38 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 39 of Set 5 | namibe
# Processing Record 40 of Set 5 | mayumba
# Processing Record 41 of Set 5 | yerbogachen
# Processing Record 42 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 5 | enterprise
# Processing Record 44 of Set 5 | manokwari
# Processing Record 45 of Set 5 | saint george
# Processing Record 46 of Set 5 | quelimane
# Processing Record 47 of Set 5 | rio grande
# Processing Record 48 of Set 5 | cagliari
# Processing Record 49 of Set 5 | lobito
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | coracao de jesus
# Processing Record 2 of Set 6 | hatillo
# Processing Record 3 of Set 6 | taft
# Processing Record 4 of Set 6 | nalut
# Processing Record 5 of Set 6 | svetlogorsk
# Processing Record 6 of Set 6 | el copey
# Processing Record 7 of Set 6 | tiksi
# Processing Record 8 of Set 6 | teguldet
# Processing Record 9 of Set 6 | linxia
# Processing Record 10 of Set 6 | grindavik
# Processing Record 11 of Set 6 | carutapera
# Processing Record 12 of Set 6 | gogosari
# Processing Record 13 of Set 6 | kanniyakumari
# Processing Record 14 of Set 6 | ertil
# Processing Record 15 of Set 6 | coalinga
# Processing Record 16 of Set 6 | ariquemes
# Processing Record 17 of Set 6 | belyy yar
# Processing Record 18 of Set 6 | whitehorse
# Processing Record 19 of Set 6 | liverpool
# Processing Record 20 of Set 6 | caravelas
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | lahij
# Processing Record 23 of Set 6 | port keats
# Processing Record 24 of Set 6 | maningrida
# Processing Record 25 of Set 6 | gboko
# Processing Record 26 of Set 6 | moose factory
# Processing Record 27 of Set 6 | raudeberg
# Processing Record 28 of Set 6 | porbandar
# Processing Record 29 of Set 6 | husavik
# Processing Record 30 of Set 6 | mayo
# Processing Record 31 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | calvinia
# Processing Record 33 of Set 6 | sola
# Processing Record 34 of Set 6 | kiama
# Processing Record 35 of Set 6 | xiamen
# Processing Record 36 of Set 6 | gao
# Processing Record 37 of Set 6 | aklavik
# Processing Record 38 of Set 6 | daru
# Processing Record 39 of Set 6 | molango
# Processing Record 40 of Set 6 | keti bandar
# Processing Record 41 of Set 6 | naze
# Processing Record 42 of Set 6 | dingle
# Processing Record 43 of Set 6 | sept-iles
# Processing Record 44 of Set 6 | klaksvik
# Processing Record 45 of Set 6 | thompson
# Processing Record 46 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 6 | isangel
# Processing Record 48 of Set 6 | yar-sale
# Processing Record 49 of Set 6 | guerrero negro
# Processing Record 50 of Set 6 | pindiga
# Processing Record 1 of Set 7 | santo estevao
# Processing Record 2 of Set 7 | tlaxiaco
# City not found. Skipping...
# Processing Record 3 of Set 7 | chaihe
# Processing Record 4 of Set 7 | rampura
# Processing Record 5 of Set 7 | mao
# Processing Record 6 of Set 7 | te anau
# Processing Record 7 of Set 7 | myitkyina
# Processing Record 8 of Set 7 | gimli
# Processing Record 9 of Set 7 | lerwick
# Processing Record 10 of Set 7 | vokhma
# Processing Record 11 of Set 7 | bardiyah
# Processing Record 12 of Set 7 | leshukonskoye
# Processing Record 13 of Set 7 | gushikawa
# Processing Record 14 of Set 7 | tigil
# Processing Record 15 of Set 7 | atar
# Processing Record 16 of Set 7 | salalah
# Processing Record 17 of Set 7 | billings
# Processing Record 18 of Set 7 | gornyy
# Processing Record 19 of Set 7 | chuy
# Processing Record 20 of Set 7 | great yarmouth
# Processing Record 21 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 7 | sao raimundo nonato
# Processing Record 23 of Set 7 | gat
# Processing Record 24 of Set 7 | solnechnyy
# Processing Record 25 of Set 7 | nouakchott
# Processing Record 26 of Set 7 | sechura
# Processing Record 27 of Set 7 | ati
# Processing Record 28 of Set 7 | colac
# Processing Record 29 of Set 7 | karratha
# Processing Record 30 of Set 7 | thinadhoo
# Processing Record 31 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 7 | san javier
# Processing Record 33 of Set 7 | berdigestyakh
# Processing Record 34 of Set 7 | kavieng
# Processing Record 35 of Set 7 | choix
# Processing Record 36 of Set 7 | ouadda
# Processing Record 37 of Set 7 | arlit
# Processing Record 38 of Set 7 | salinopolis
# Processing Record 39 of Set 7 | bengkulu
# Processing Record 40 of Set 7 | porto novo
# Processing Record 41 of Set 7 | hornepayne
# Processing Record 42 of Set 7 | poum
# Processing Record 43 of Set 7 | severo-kurilsk
# Processing Record 44 of Set 7 | boralday
# Processing Record 45 of Set 7 | neiafu
# Processing Record 46 of Set 7 | phuket
# Processing Record 47 of Set 7 | vaitape
# Processing Record 48 of Set 7 | todos santos
# Processing Record 49 of Set 7 | walvis bay
# Processing Record 50 of Set 7 | lamont
# Processing Record 1 of Set 8 | bakchar
# Processing Record 2 of Set 8 | vilani
# Processing Record 3 of Set 8 | maxixe
# Processing Record 4 of Set 8 | dalbandin
# Processing Record 5 of Set 8 | kayerkan
# Processing Record 6 of Set 8 | cayenne
# Processing Record 7 of Set 8 | mont-dore
# Processing Record 8 of Set 8 | butembo
# Processing Record 9 of Set 8 | vardo
# Processing Record 10 of Set 8 | buarcos
# Processing Record 11 of Set 8 | batagay-alyta
# Processing Record 12 of Set 8 | lebyazhye
# Processing Record 13 of Set 8 | koumra
# Processing Record 14 of Set 8 | parabel
# Processing Record 15 of Set 8 | toora-khem
# Processing Record 16 of Set 8 | bandundu
# Processing Record 17 of Set 8 | ketchikan
# Processing Record 18 of Set 8 | sao domingos
# Processing Record 19 of Set 8 | noumea
# Processing Record 20 of Set 8 | barranco
# Processing Record 21 of Set 8 | inhambane
# Processing Record 22 of Set 8 | vanersborg
# Processing Record 23 of Set 8 | rawlins
# Processing Record 24 of Set 8 | plettenberg bay
# Processing Record 25 of Set 8 | tyrma
# Processing Record 26 of Set 8 | yichang
# Processing Record 27 of Set 8 | kamra
# Processing Record 28 of Set 8 | nome
# Processing Record 29 of Set 8 | sinnamary
# Processing Record 30 of Set 8 | langsa
# Processing Record 31 of Set 8 | oxelosund
# Processing Record 32 of Set 8 | beringovskiy
# Processing Record 33 of Set 8 | geraldton
# Processing Record 34 of Set 8 | la ronge
# Processing Record 35 of Set 8 | buraydah
# Processing Record 36 of Set 8 | tucupita
# Processing Record 37 of Set 8 | manaure
# Processing Record 38 of Set 8 | pangody
# Processing Record 39 of Set 8 | mandalgovi
# Processing Record 40 of Set 8 | laguna
# Processing Record 41 of Set 8 | bodoco
# City not found. Skipping...
# Processing Record 42 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 43 of Set 8 | margate
# Processing Record 44 of Set 8 | dali
# Processing Record 45 of Set 8 | yamada
# Processing Record 46 of Set 8 | brae
# Processing Record 47 of Set 8 | severo-yeniseyskiy
# Processing Record 48 of Set 8 | skibbereen
# Processing Record 49 of Set 8 | palmer
# Processing Record 50 of Set 8 | collie
# Processing Record 1 of Set 9 | pemba
# Processing Record 2 of Set 9 | qaqortoq
# Processing Record 3 of Set 9 | gouyave
# Processing Record 4 of Set 9 | seshcha
# Processing Record 5 of Set 9 | sur
# Processing Record 6 of Set 9 | la tuque
# Processing Record 7 of Set 9 | uthal
# Processing Record 8 of Set 9 | shenjiamen
# Processing Record 9 of Set 9 | chissamba
# Processing Record 10 of Set 9 | talaya
# Processing Record 11 of Set 9 | san quintin
# Processing Record 12 of Set 9 | vanavara
# Processing Record 13 of Set 9 | murashi
# Processing Record 14 of Set 9 | awallan
# Processing Record 15 of Set 9 | bandarbeyla
# Processing Record 16 of Set 9 | rock sound
# Processing Record 17 of Set 9 | rocha
# Processing Record 18 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 19 of Set 9 | tuatapere
# Processing Record 20 of Set 9 | nemuro
# Processing Record 21 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 9 | srednekolymsk
# Processing Record 23 of Set 9 | puerto baquerizo moreno
# Processing Record 24 of Set 9 | venice
# Processing Record 25 of Set 9 | flinders
# Processing Record 26 of Set 9 | toamasina
# Processing Record 27 of Set 9 | fairmont
# Processing Record 28 of Set 9 | eskisehir
# Processing Record 29 of Set 9 | ishigaki
# Processing Record 30 of Set 9 | santa marinella
# Processing Record 31 of Set 9 | shergarh
# Processing Record 32 of Set 9 | coruripe
# Processing Record 33 of Set 9 | sosnogorsk
# Processing Record 34 of Set 9 | samarai
# Processing Record 35 of Set 9 | hanzhong
# Processing Record 36 of Set 9 | kloulklubed
# Processing Record 37 of Set 9 | hamilton
# Processing Record 38 of Set 9 | udachnyy
# Processing Record 39 of Set 9 | cotonou
# Processing Record 40 of Set 9 | itacare
# Processing Record 41 of Set 9 | pirganj
# Processing Record 42 of Set 9 | ayorou
# Processing Record 43 of Set 9 | nadym
# Processing Record 44 of Set 9 | rawson
# Processing Record 45 of Set 9 | bada
# Processing Record 46 of Set 9 | haines junction
# Processing Record 47 of Set 9 | sao jose da coroa grande
# Processing Record 48 of Set 9 | coos bay
# Processing Record 49 of Set 9 | nipawin
# Processing Record 50 of Set 9 | kargasok
# Processing Record 1 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 10 | pocao de pedras
# Processing Record 3 of Set 10 | abengourou
# Processing Record 4 of Set 10 | cobija
# Processing Record 5 of Set 10 | veraval
# Processing Record 6 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 10 | yulin
# Processing Record 8 of Set 10 | half moon bay
# Processing Record 9 of Set 10 | hirara
# Processing Record 10 of Set 10 | coquimbo
# Processing Record 11 of Set 10 | cetateni
# Processing Record 12 of Set 10 | araouane
# Processing Record 13 of Set 10 | aksay
# Processing Record 14 of Set 10 | roald
# Processing Record 15 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 10 | codrington
# Processing Record 17 of Set 10 | dumas
# Processing Record 18 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 10 | turayf
# Processing Record 20 of Set 10 | liwale
# Processing Record 21 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 22 of Set 10 | belmonte
# Processing Record 23 of Set 10 | pochutla
# Processing Record 24 of Set 10 | sioux lookout
# Processing Record 25 of Set 10 | cap malheureux
# Processing Record 26 of Set 10 | hailar
# Processing Record 27 of Set 10 | tibati
# Processing Record 28 of Set 10 | rafaela
# Processing Record 29 of Set 10 | cabo san lucas
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | mastic beach
# Processing Record 32 of Set 10 | bijie
# Processing Record 33 of Set 10 | north platte
# Processing Record 34 of Set 10 | pierre
# Processing Record 35 of Set 10 | buritis
# Processing Record 36 of Set 10 | iqaluit
# Processing Record 37 of Set 10 | pombia
# Processing Record 38 of Set 10 | semey
# Processing Record 39 of Set 10 | dedovichi
# Processing Record 40 of Set 10 | springdale
# Processing Record 41 of Set 10 | sao filipe
# Processing Record 42 of Set 10 | tumpat
# Processing Record 43 of Set 10 | nuevo progreso
# Processing Record 44 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 10 | trelew
# Processing Record 46 of Set 10 | ambilobe
# Processing Record 47 of Set 10 | castro
# Processing Record 48 of Set 10 | mahon
# Processing Record 49 of Set 10 | rantepao
# Processing Record 50 of Set 10 | kristiinankaupunki
# Processing Record 1 of Set 11 | elko
# Processing Record 2 of Set 11 | termini imerese
# Processing Record 3 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 11 | tabas
# Processing Record 5 of Set 11 | norman wells
# Processing Record 6 of Set 11 | methoni
# Processing Record 7 of Set 11 | patratu
# City not found. Skipping...
# Processing Record 8 of Set 11 | xining
# Processing Record 9 of Set 11 | villazon
# Processing Record 10 of Set 11 | santiago del estero
# Processing Record 11 of Set 11 | loanda
# Processing Record 12 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 11 | kihei
# Processing Record 14 of Set 11 | villa altagracia
# Processing Record 15 of Set 11 | nagato
# Processing Record 16 of Set 11 | kargil
# Processing Record 17 of Set 11 | kumhari
# Processing Record 18 of Set 11 | la serena
# Processing Record 19 of Set 11 | youhao
# Processing Record 20 of Set 11 | bahawalpur
# Processing Record 21 of Set 11 | manado
# Processing Record 22 of Set 11 | bukachacha
# Processing Record 23 of Set 11 | hofn
# Processing Record 24 of Set 11 | quarteira
# Processing Record 25 of Set 11 | great falls
# Processing Record 26 of Set 11 | leningradskiy
# Processing Record 27 of Set 11 | byron bay
# Processing Record 28 of Set 11 | muana
# Processing Record 29 of Set 11 | lavrentiya
# Processing Record 30 of Set 11 | los llanos de aridane
# Processing Record 31 of Set 11 | nishihara
# Processing Record 32 of Set 11 | imeni poliny osipenko
# Processing Record 33 of Set 11 | talcahuano
# Processing Record 34 of Set 11 | beloha
# Processing Record 35 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 11 | strai
# Processing Record 37 of Set 11 | amudat
# Processing Record 38 of Set 11 | khorinsk
# Processing Record 39 of Set 11 | kalemie
# Processing Record 40 of Set 11 | kahama
# Processing Record 41 of Set 11 | gurupi
# Processing Record 42 of Set 11 | tual
# Processing Record 43 of Set 11 | yulara
# Processing Record 44 of Set 11 | ixtapa
# Processing Record 45 of Set 11 | sitka
# Processing Record 46 of Set 11 | tahta
# Processing Record 47 of Set 11 | biograd na moru
# Processing Record 48 of Set 11 | lianzhou
# Processing Record 49 of Set 11 | paamiut
# Processing Record 50 of Set 11 | ribas do rio pardo
# Processing Record 1 of Set 12 | touros
# Processing Record 2 of Set 12 | amga
# Processing Record 3 of Set 12 | gamba
# Processing Record 4 of Set 12 | takoradi
# Processing Record 5 of Set 12 | jiayuguan
# Processing Record 6 of Set 12 | tawau
# Processing Record 7 of Set 12 | ambon
# Processing Record 8 of Set 12 | ambulu
# Processing Record 9 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 12 | ouango
# Processing Record 11 of Set 12 | dawson creek
# Processing Record 12 of Set 12 | necochea
# Processing Record 13 of Set 12 | brigantine
# Processing Record 14 of Set 12 | victor harbor
# Processing Record 15 of Set 12 | miedzyrzecz
# Processing Record 16 of Set 12 | sao miguel do araguaia
# Processing Record 17 of Set 12 | san francisco
# Processing Record 18 of Set 12 | sistranda
# Processing Record 19 of Set 12 | kununurra
# Processing Record 20 of Set 12 | khilok
# Processing Record 21 of Set 12 | markova
# Processing Record 22 of Set 12 | pombas
# Processing Record 23 of Set 12 | wanning
# Processing Record 24 of Set 12 | gawler
# Processing Record 25 of Set 12 | waingapu
# Processing Record 26 of Set 12 | dwarka
# Processing Record 27 of Set 12 | kidal
# Processing Record 28 of Set 12 | huercal-overa
# Processing Record 29 of Set 12 | fort morgan
# Processing Record 30 of Set 12 | vandra
# Processing Record 31 of Set 12 | sume
# Processing Record 32 of Set 12 | winnemucca
# Processing Record 33 of Set 12 | henties bay
# Processing Record 34 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 35 of Set 12 | donskoye
# Processing Record 36 of Set 12 | shibetsu
# Processing Record 37 of Set 12 | swan hill
# Processing Record 38 of Set 12 | sisimiut
# Processing Record 39 of Set 12 | thilogne
# City not found. Skipping...
# Processing Record 40 of Set 12 | basco
# Processing Record 41 of Set 12 | pisco
# Processing Record 42 of Set 12 | kostomuksha
# Processing Record 43 of Set 12 | xai-xai
# Processing Record 44 of Set 12 | matara
# Processing Record 45 of Set 12 | santa barbara
# Processing Record 46 of Set 12 | puerto cabezas
# Processing Record 47 of Set 12 | bhilwara
# Processing Record 48 of Set 12 | kismayo
# Processing Record 49 of Set 12 | sandwick
# Processing Record 50 of Set 12 | aquiraz
# Processing Record 1 of Set 13 | palmerston
# Processing Record 2 of Set 13 | north bend
# Processing Record 3 of Set 13 | zabol
# Processing Record 4 of Set 13 | chipata
# Processing Record 5 of Set 13 | formosa
# Processing Record 6 of Set 13 | mogadishu
# Processing Record 7 of Set 13 | harrismith
# Processing Record 8 of Set 13 | grajau
# Processing Record 9 of Set 13 | kaliua
# Processing Record 10 of Set 13 | ziro
# Processing Record 11 of Set 13 | chimore
# Processing Record 12 of Set 13 | vestmannaeyjar
# Processing Record 13 of Set 13 | karanganom
# Processing Record 14 of Set 13 | san antonio
# Processing Record 15 of Set 13 | vitre
# Processing Record 16 of Set 13 | abu zabad
# Processing Record 17 of Set 13 | nenjiang
# Processing Record 18 of Set 13 | springbok
# Processing Record 19 of Set 13 | madison
# Processing Record 20 of Set 13 | kang
# Processing Record 21 of Set 13 | san juan
# Processing Record 22 of Set 13 | healdsburg
# Processing Record 23 of Set 13 | baykit
# Processing Record 24 of Set 13 | bambanglipuro
# Processing Record 25 of Set 13 | san patricio
# Processing Record 26 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 13 | philippeville
# Processing Record 28 of Set 13 | havoysund
# Processing Record 29 of Set 13 | oranjemund
# Processing Record 30 of Set 13 | bonthe
# Processing Record 31 of Set 13 | richards bay
# Processing Record 32 of Set 13 | camabatela
# Processing Record 33 of Set 13 | fethiye
# Processing Record 34 of Set 13 | wilmington
# Processing Record 35 of Set 13 | burica
# City not found. Skipping...
# Processing Record 36 of Set 13 | kahului
# Processing Record 37 of Set 13 | oktyabrskiy
# Processing Record 38 of Set 13 | marfino
# Processing Record 39 of Set 13 | rio gallegos
# Processing Record 40 of Set 13 | fonte boa
# Processing Record 41 of Set 13 | alta floresta
# Processing Record 42 of Set 13 | monte patria
# Processing Record 43 of Set 13 | sarangani
# Processing Record 44 of Set 13 | labuhan
# Processing Record 45 of Set 13 | lahti
# Processing Record 46 of Set 13 | susanville
# Processing Record 47 of Set 13 | newport
# Processing Record 48 of Set 13 | norton
# Processing Record 49 of Set 13 | lazaro cardenas
# Processing Record 50 of Set 13 | finnsnes
# Processing Record 1 of Set 14 | yellamanchili
# City not found. Skipping...
# Processing Record 2 of Set 14 | fengzhen
# Processing Record 3 of Set 14 | kenai
# Processing Record 4 of Set 14 | surt
# Processing Record 5 of Set 14 | salaga
# Processing Record 6 of Set 14 | wageningen
# Processing Record 7 of Set 14 | williston
# Processing Record 8 of Set 14 | izumo
# Processing Record 9 of Set 14 | panguipulli
# Processing Record 10 of Set 14 | egvekinot
# Processing Record 11 of Set 14 | grand gaube
# Processing Record 12 of Set 14 | kavaratti
# Processing Record 13 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 14 | chapais
# Processing Record 15 of Set 14 | ubinskoye
# Processing Record 16 of Set 14 | bar harbor
# Processing Record 17 of Set 14 | parana
# Processing Record 18 of Set 14 | ndioum
# Processing Record 19 of Set 14 | kochubey
# Processing Record 20 of Set 14 | zainsk
# Processing Record 21 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 14 | moindou
# Processing Record 23 of Set 14 | dawei
# Processing Record 24 of Set 14 | kesinga
# Processing Record 25 of Set 14 | ilula
# Processing Record 26 of Set 14 | wattegama
# Processing Record 27 of Set 14 | port blair
# Processing Record 28 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 30 of Set 14 | soyo
# Processing Record 31 of Set 14 | lekoni
# Processing Record 32 of Set 14 | san antonio del norte
# Processing Record 33 of Set 14 | gazojak
# Processing Record 34 of Set 14 | oranjestad
# Processing Record 35 of Set 14 | vila velha
# Processing Record 36 of Set 14 | araguatins
# City not found. Skipping...
# Processing Record 37 of Set 14 | krasnaya gora
# Processing Record 38 of Set 14 | santa marta
# Processing Record 39 of Set 14 | kontagora
# Processing Record 40 of Set 14 | yarkovo
# Processing Record 41 of Set 14 | ovsyanka
# Processing Record 42 of Set 14 | auki
# Processing Record 43 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 14 | hoquiam
# Processing Record 45 of Set 14 | guadalupe victoria
# Processing Record 46 of Set 14 | kangaba
# Processing Record 47 of Set 14 | komatipoort
# Processing Record 48 of Set 14 | barranca
# Processing Record 49 of Set 14 | christchurch
# Processing Record 50 of Set 14 | luena
# Processing Record 1 of Set 15 | debre tabor
# Processing Record 2 of Set 15 | kindu
# Processing Record 3 of Set 15 | sibolga
# Processing Record 4 of Set 15 | antofagasta
# Processing Record 5 of Set 15 | taoudenni
# Processing Record 6 of Set 15 | goderich
# Processing Record 7 of Set 15 | kudahuvadhoo
# Processing Record 8 of Set 15 | sarahan
# Processing Record 9 of Set 15 | valparaiso
# Processing Record 10 of Set 15 | chara
# Processing Record 11 of Set 15 | yumen
# Processing Record 12 of Set 15 | tashtyp
# Processing Record 13 of Set 15 | pangnirtung
# Processing Record 14 of Set 15 | buala
# Processing Record 15 of Set 15 | monrovia
# Processing Record 16 of Set 15 | burriana
# Processing Record 17 of Set 15 | tikapur
# Processing Record 18 of Set 15 | moerai
# Processing Record 19 of Set 15 | jalu
# Processing Record 20 of Set 15 | santa maria
# Processing Record 21 of Set 15 | gobabis
# Processing Record 22 of Set 15 | yeniseysk
# Processing Record 23 of Set 15 | sakaiminato
# Processing Record 24 of Set 15 | le port
# Processing Record 25 of Set 15 | mayachnyy
# Processing Record 26 of Set 15 | komsomolskiy
# Processing Record 27 of Set 15 | mount gambier
# Processing Record 28 of Set 15 | conde
# Processing Record 29 of Set 15 | santa rosa
# Processing Record 30 of Set 15 | savannakhet
# Processing Record 31 of Set 15 | diamantino
# Processing Record 32 of Set 15 | searcy
# Processing Record 33 of Set 15 | nzega
# Processing Record 34 of Set 15 | lac du bonnet
# Processing Record 35 of Set 15 | pringsewu
# Processing Record 36 of Set 15 | sainte-rose
# Processing Record 37 of Set 15 | diu
# Processing Record 38 of Set 15 | peniche
# Processing Record 39 of Set 15 | killin
# Processing Record 40 of Set 15 | kiruna
# Processing Record 41 of Set 15 | belen
# Processing Record 42 of Set 15 | vredendal
# Processing Record 43 of Set 15 | ust-kuyga
# Processing Record 44 of Set 15 | ahuimanu
# Processing Record 45 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 15 | princeton
# Processing Record 47 of Set 15 | meiganga
# Processing Record 48 of Set 15 | gambela
# Processing Record 49 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 15 | villa maria
# Processing Record 1 of Set 16 | kulhudhuffushi
# Processing Record 2 of Set 16 | troitskoye
# Processing Record 3 of Set 16 | makat
# Processing Record 4 of Set 16 | praia da vitoria
# Processing Record 5 of Set 16 | riyadh
# Processing Record 6 of Set 16 | tulun
# Processing Record 7 of Set 16 | champerico
# Processing Record 8 of Set 16 | galveston
# Processing Record 9 of Set 16 | seoul
# Processing Record 10 of Set 16 | hami
# Processing Record 11 of Set 16 | kologriv
# Processing Record 12 of Set 16 | wiarton
# Processing Record 13 of Set 16 | lumphat
# Processing Record 14 of Set 16 | changping
# Processing Record 15 of Set 16 | puerto madryn
# Processing Record 16 of Set 16 | belle glade
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 716

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Lincoln      AU -34.73  135.87     59.94        75          67
# 1     Rongcheng      CN  30.63  117.85     58.05        90          66
# 2        Kisesa      TZ  -3.08   34.15     71.06        60          66
# 3       Halifax      CA  44.65  -63.57     39.99        78          20
# 4    Santa Cruz      BO -17.80  -63.17     87.84        48           4
#
#    Wind Speed Current Description
# 0       21.70       broken clouds
# 1        3.58       broken clouds
# 2        6.91       broken clouds
# 3        1.01          few clouds
# 4       13.65           clear sky

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
